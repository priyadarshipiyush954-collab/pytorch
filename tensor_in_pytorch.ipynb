# %%
import torch
print(torch.version)
# Out:
# <module 'torch.version' from 'd:\\d drive\\AN\\envs\\gpu_env\\lib\\site-packages\\torch\\version.py'>

# %%
if torch.cuda.is_available():
    print("GPU is avaliable")
    print(f"using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. Using CPU.")
# Out:
# GPU is avaliable
# using GPU: NVIDIA GeForce RTX 4050 Laptop GPU

# %% [markdown]
# # Create Tensor

# %%
# using empty 
torch.empty(2,3)
# Out:
# tensor([[2.4932e+35, 1.3074e-42, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00]])

# %%
x = torch.tensor([[1,2,3],[4,5,6]])
x
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %%
x.dtype
# Out:
# torch.int64

# %%
# addition 
x +2
# sub
x-3
#multiplication
x*3
# Out:
# 15
