# %%
import torch
print(torch.version)
# Out:
# <module 'torch.version' from 'd:\\d drive\\AN\\envs\\gpu_env\\lib\\site-packages\\torch\\version.py'>

# %%
if torch.cuda.is_available():
    print("GPU is avaliable")
    print(f"using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. Using CPU.")
# Out:
# GPU is avaliable
# using GPU: NVIDIA GeForce RTX 4050 Laptop GPU

# %% [markdown]
# # Create Tensor

# %%
# using empty 
torch.empty(2,3)
# Out:
# tensor([[7.0407e+13, 1.1883e-42, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00]])

# %%
x = torch.tensor([[1,2,3],[4,5,6]])
x
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %%
x.dtype
# Out:
# torch.int64

# %%
# addition 
x +2
# sub
x-3
#multiplication
x*3
# Out:
# 15

# %% [markdown]
# # Matrix

# %%
f = torch.randint(size=(2,3),low=0, high=10)
g = torch.randint(size=(3,2),low =0 , high =10)

print(f)
print(g)
# Out:
# tensor([[5, 3, 5],
#         [6, 5, 1]])
# tensor([[1, 0],
#         [7, 5],
#         [3, 1]])

# %%
# matrix multiplication
torch.matmul(f,g)
# Out:
# tensor([[41, 20],
#         [44, 26]])

# %%
vector1 = torch.tensor([1,2])
vector2 = torch.tensor([3,4])

# dot product
torch.dot(vector1,vector2)
# Out:
# tensor(11)

# %%
torch.transpose(f,0,1)
# Out:
# tensor([[5, 6],
#         [3, 5],
#         [5, 1]])

# %% [markdown]
# # Comparison operations

# %%
i = torch.randint(size=(2,3),low=0,high=10)
j = torch.randint(size=(2,3),low=0,high=10 , dtype =torch.float32)

print(i)
print(j)
# Out:
# tensor([[7, 0, 5],
#         [7, 5, 0]])
# tensor([[4., 6., 1.],
#         [4., 4., 5.]])

# %%
# greater then 
i > j
#less then
i>j
# Out:
# tensor([[ True, False, False],
#         [ True, False, False]])

# %%
torch.log(j)
# Out:
# tensor([[  -inf, 2.1972, 1.9459],
#         [0.0000, 1.3863, 0.6931]])

# %%
torch.exp(j)
# Out:
# tensor([[1.0000e+00, 8.1031e+03, 1.0966e+03],
#         [2.7183e+00, 5.4598e+01, 7.3891e+00]])

# %%
torch.sqrt(j)
# Out:
# tensor([[0.0000, 3.0000, 2.6458],
#         [1.0000, 2.0000, 1.4142]])

# %%
torch.sigmoid(j)
# Out:
# tensor([[0.5000, 0.9999, 0.9991],
#         [0.7311, 0.9820, 0.8808]])

# %%
torch.softmax(j,dim=0)
# Out:
# tensor([[0.5000, 0.8808, 0.0180],
#         [0.5000, 0.1192, 0.9820]])

# %%
torch.relu(j)
# Out:
# tensor([[4., 6., 1.],
#         [4., 4., 5.]])

# %% [markdown]
# # Inplace Operation

# %%
m = torch.rand(2,3)
n= torch.rand(2,3)

print(m)
print(n)
# Out:
# tensor([[0.3887, 0.8861, 0.5123],
#         [0.0633, 0.0813, 0.5882]])
# tensor([[0.3359, 0.3192, 0.4295],
#         [0.3039, 0.4512, 0.2905]])

# %%
m.add_(n)
# Out:
# tensor([[0.7246, 1.2053, 0.9418],
#         [0.3673, 0.5325, 0.8787]])

# %%
torch.relu(m)
# Out:
# tensor([[0.7246, 1.2053, 0.9418],
#         [0.3673, 0.5325, 0.8787]])

# %% [markdown]
# # Tensor Operations Gpu

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda')

# %%
torch.rand((2,3),device=device)
# Out:
# tensor([[0.2192, 0.5336, 0.8447],
#         [0.8894, 0.0339, 0.2373]], device='cuda:0')
